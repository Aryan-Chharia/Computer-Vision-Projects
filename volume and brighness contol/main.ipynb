# %%
# install requeried libraries
# !pip install opencv-python 
# !pip install mediapipe 
# !pip install screen-brightness-control 
# !pip install pycaw 
# !pip install comtypes
# Out:
# Requirement already satisfied: opencv-python in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from opencv-python) (1.24.4)
# Requirement already satisfied: mediapipe in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (0.10.11)
# Requirement already satisfied: absl-py in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (0.4.13)
# Requirement already satisfied: matplotlib in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (3.7.5)
# Requirement already satisfied: numpy in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (1.24.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jax->mediapipe) (1.10.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from jax->mediapipe) (8.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->mediapipe) (6.4.4)
# Requirement already satisfied: pycparser in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: zipp>=0.5 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Requirement already satisfied: screen-brightness-control in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (0.23.0)
# Requirement already satisfied: wmi in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from screen-brightness-control) (1.5.1)
# Requirement already satisfied: pywin32 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from screen-brightness-control) (306)
# Requirement already satisfied: pypiwin32 in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from screen-brightness-control) (223)
# Requirement already satisfied: pycaw in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (20240210)
# Requirement already satisfied: comtypes in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pycaw) (1.4.7)
# Requirement already satisfied: psutil in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pycaw) (6.0.0)
# Requirement already satisfied: comtypes in c:\users\hai\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (1.4.7)

# %%
import cv2
import numpy as np
import mediapipe as mp
from screen_brightness_control import set_brightness
from ctypes import cast, POINTER
from comtypes import CLSCTX_ALL
from pycaw.pycaw import AudioUtilities, IAudioEndpointVolume

# Initialize Mediapipe and OpenCV
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1)
mp_draw = mp.solutions.drawing_utils

# Setup audio control
devices = AudioUtilities.GetSpeakers()
interface = devices.Activate(IAudioEndpointVolume._iid_, CLSCTX_ALL, None)
volume = cast(interface, POINTER(IAudioEndpointVolume))
vol_range = volume.GetVolumeRange()
min_vol = vol_range[0]
max_vol = vol_range[1]

cap = cv2.VideoCapture(0)

while True:
    success, img = cap.read()
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    if results.multi_hand_landmarks:
        for hand_lms in results.multi_hand_landmarks:
            # Get thumb and index tip positions
            thumb_tip = hand_lms.landmark[4]
            index_tip = hand_lms.landmark[8]

            h, w, _ = img.shape
            thumb_coords = (int(thumb_tip.x * w), int(thumb_tip.y * h))
            index_coords = (int(index_tip.x * w), int(index_tip.y * h))

            # Draw landmarks
            mp_draw.draw_landmarks(img, hand_lms, mp_hands.HAND_CONNECTIONS)

            # Calculate distance between thumb and index
            distance = np.linalg.norm(np.array(thumb_coords) - np.array(index_coords))

            # Normalize distance to volume range
            vol = np.interp(distance, [30, 300], [min_vol, max_vol])
            volume.SetMasterVolumeLevel(vol, None)

            # Control brightness (as a percentage)
            brightness = np.interp(distance, [30, 300], [0, 100])
            set_brightness(int(brightness))

            # Display controls
            cv2.putText(img, f'Volume: {int((vol - min_vol) / (max_vol - min_vol) * 100)}%', (50, 50),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(img, f'Brightness: {int(brightness)}%', (50, 100),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    cv2.imshow('Img', img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
